# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/home/alexandre/Downloads/New_York_City_Leading_Causes_of_Death_20250213.csv")
dataset
# Out:
#       Year str                                   LeadingCause str Sex str  \
# 0         2007                        Diabetes Mellitus (E10-E14)       M
# 1         2010     Diseases of Heart (I00-I09, I11, I13, I20-I51)       F
# 2         2007          Cerebrovascular Disease (Stroke: I60-I69)       M
# 3         2007                              Atherosclerosis (I70)       F
# 4         2014              Malignant Neoplasms (Cancer: C00-C97)       F
# ...        ...                                                ...     ...
# 1089      2013                                   All Other Causes       M
# 1090      2009     Diseases of Heart (I00-I09, I11, I13, I20-I51)       M
# 1091      2008  Human Immunodeficiency Virus Disease (HIV: B20...       M
# 1092      2010       Chronic Lower Respiratory Diseases (J40-J47)       M
# 1093      2013  Nephritis, Nephrotic Syndrome and Nephrisis (N...       F
#
#           RaceEthnicity str  Deaths int  DeathRate float  \
# ...

# %%
df_shuffled = dataset.copy()
for column in df_shuffled.columns:
    df_shuffled[column] = np.random.permutation(df_shuffled[column])

df_shuffled
# Out:
#       Year str                                   LeadingCause str Sex str  \
# 0         2014  Accidents Except Drug Posioning (V01-X39, X43,...       M
# 1         2007  Accidents Except Drug Posioning (V01-X39, X43,...       F
# 2         2010       Chronic Lower Respiratory Diseases (J40-J47)       F
# 3         2009                                   All Other Causes       M
# 4         2008     Diseases of Heart (I00-I09, I11, I13, I20-I51)       F
# ...        ...                                                ...     ...
# 1089      2009     Diseases of Heart (I00-I09, I11, I13, I20-I51)       M
# 1090      2007  Accidents Except Drug Posioning (V01-X39, X43,...       F
# 1091      2013                          Alzheimer's Disease (G30)       F
# 1092      2008                                   All Other Causes       F
# 1093      2010     Diseases of Heart (I00-I09, I11, I13, I20-I51)       F
#
#                RaceEthnicity str  Deaths int  DeathRate float  \
# ...

# %%
df_shuffled.to_csv("../datasets/nycdeaths_shuffled.csv", quotechar="\"")
