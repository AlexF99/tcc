# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("../datasets/Queens_Library_Branches_20250211.csv")
dataset
# Out:
#                          name str                   Address str  \
# 0                        Rosedale             144-20 243 Street
# 1                         Bayside     214-20 Northern Boulevard
# 2   Central Library- The Archives       89-11 Merrick Boulevard
# 3                          Hollis        202-05 Hillside Avenue
# 4        Queens Library for Teens              2002 Cornaga Ave
# ..                            ...                           ...
# 63                   Queensbridge  Now a Family Literacy Center
# 64               Rochdale Village             169-09 137 Avenue
# 65                       Flushing             41-17 Main Street
# 66                Central Library       89-11 Merrick Boulevard
# 67                        Arverne           312 Beach 54 Street
#
#               City str  Postcode str       phone str              Mn str  \
# 0             Rosedale         11422  (718) 528-8490  12:00 PM - 8:00 PM
# ...

# %%
df_shuffled = dataset.copy()
for column in df_shuffled.columns:
    df_shuffled[column] = np.random.permutation(df_shuffled[column])

df_shuffled
# Out:
#            name str                Address str           City str  \
# 0   Langston Hughes    89-11 Merrick Boulevard   Long Island City
# 1         Briarwood  98-27 Metropolitan Avenue         Ozone Park
# 2   Cambria Heights       25-01 Jackson Avenue           Flushing
# 3   Mitchell-Linden        1637 Central Avenue            Bayside
# 4       Lefrak City         69-70 Grand Avenue     Queens Village
# ..              ...                        ...                ...
# 63  Queensboro Hill             78-60 73 Place       South Hollis
# 64           Corona             151-10 14 Road          Rego Park
# 65          Pomonok          134-26 225 Street             Corona
# 66         Glendale  100-01 Northern Boulevard  35-32 21 St., LIC
# 67         Woodside  214-20 Northern Boulevard          Laurelton
#
#     Postcode str       phone str              Mn str             Tu str  \
# 0          11426  (718) 591-4343  12:00 PM - 8:00 PM  1:00 PM - 6:00 PM
# ...

# %%
df_shuffled.to_csv("../datasets/queens_shuffled.csv", quotechar="\"")
