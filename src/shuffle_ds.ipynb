# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("../datasets/ncvoter_1001r_19c.csv")
dataset
# Out:
#      voter_id  voter_reg_num name_prefix first_name middle_name  last_name  \
# 0           0   990000454758         NaN     rodney        john   glockner
# 1           1   999000021841         NaN     sallie     wilkins  blanchard
# 2           2   999000027078         NaN       john           m    goodson
# 3           3   990002064270         NaN     glenda        ware     battle
# 4           4   990004004166         NaN    michele      koenig    bullock
# ..        ...            ...         ...        ...         ...        ...
# 995       994   999000546314         NaN      edith       dixon     pender
# 996       995   999000560430         NaN       ruth           e       todd
# 997       996   999000587730         NaN      james      wilson       dunn
# 998       997   999000608537         NaN  josephine       smith        cox
# 999       998   999000618857         NaN    everett         mrs      james
#
#     name_suffix  age gender race ethnic            street_address  \
# 0           NaN   37      m    w     nl    1708 pembroke jones dr
# 1           NaN  111      f    w     nl             203 e main st
# 2           NaN  102      m    w     nl        496 white flash rd
# 3           NaN   56      f    b     nl       15360 pea bridge rd
# 4           NaN   53      f    w     nl          242 northwood dr
# ..          ...  ...    ...  ...    ...                       ...
# 995         NaN   97      f    w     nl          202 n seventh st
# 996         NaN   95      f    w     nl         1309 jonestown rd
# 997         NaN   98      m    w     nl  3639 spangenberg ave #4a
# 998         NaN   97      f    w     nl           512 boundary st
# 999         NaN   94      f    w     nl   2263 w clemmonsville rd
#
#               city state  zip_code full_phone_num birth_place register_date  \
# 0       wilmington    nc     28405   910 509 3864          nj    01/01/1930
# 1        rose hill    nc     28458   910 289 3320          nc    01/01/1930
# 2         mt olive    nc     28365   910 658 3413          nc    01/01/1930
# 3       laurinburg    nc     28352            NaN         NaN    10/01/1930
# 4       whiteville    nc     28472            NaN          pa    10/01/1930
# ..             ...   ...       ...            ...         ...           ...
# 995         mebane    nc     27302            NaN          nc    10/26/1940
# 996  winston salem    nc     27103            NaN          nc    10/26/1940
# 997       clemmons    nc     27012            NaN          nc    10/26/1940
# 998      haw river    nc     27258       578 0024          nc    10/26/1940
# 999  winston salem    nc     27127            NaN          nc    10/26/1940
#
#     download_month
# 0          2011-10
# 1          2011-12
# 2          2011-12
# 3          2011-10
# 4          2011-10
# ..             ...
# 995        2011-12
# 996        2011-12
# 997        2011-12
# 998        2011-12
# 999        2011-12
#
# [1000 rows x 19 columns]

# %%
df_shuffled = dataset.copy()
for column in df_shuffled.columns:
    df_shuffled[column] = np.random.permutation(df_shuffled[column])

df_shuffled
# Out:
#      voter_id  voter_reg_num name_prefix first_name middle_name last_name  \
# 0          43   999000512421         NaN     louise           r     shutt
# 1         481   990002445049         NaN       carl           t     mcrae
# 2         595   990003307474         NaN        joe           r  thompson
# 3          88   999000508980         NaN     shelby         joe     craft
# 4         597        1230928         NaN   marianne           f    raynor
# ..        ...            ...         ...        ...         ...       ...
# 995       574        6722520         NaN    broadie           c    lilley
# 996       796   999000297993         NaN     goldie           d   transou
# 997       620   990002280327         NaN          d      fenton     hurst
# 998       657        4676400         NaN     fannie      sharpe    parker
# 999       126   990000363950         NaN    frances      joseph    ingram
#
#     name_suffix  age gender race ethnic           street_address  \
# 0           NaN   70      m    w     nl     4837 sapony creek dr
# 1           NaN   97      m    w     nl         5951 n nc hwy 62
# 2           NaN   97      f    w     nl         1011 n church st
# 3           NaN  111      f    w     un            107 n main st
# 4            jr   97      m    w     nl     7376 belews creek rd
# ..          ...  ...    ...  ...    ...                      ...
# 995         NaN   75      f    w     nl           1987 hilton rd
# 996         NaN   98      f    b     nl  188 hudson cajah mtn rd
# 997         NaN   72      f    w     nl        3479 caratoke hwy
# 998         NaN  101      m    b     nl     4236 sabrina lake rd
# 999         NaN   96      m    w     nl           2344 mcrae ave
#
#               city state  zip_code full_phone_num birth_place register_date  \
# 0          henrico    nc     28659            NaN          nc    05/06/1940
# 1    winston salem    nc     27253   828 926 4197          nc    10/24/1940
# 2       burlington    nc     27217            NaN          nc    05/11/1940
# 3       burlington    nc     27106   336 364 2454          nc    01/01/1936
# 4        claremont    nc     27522            NaN          nc    01/01/1940
# ..             ...   ...       ...            ...         ...           ...
# 995     burlington    nc     28532            NaN          nc    02/06/1937
# 996    williamston    nc     27127   336 506 2643          nc    05/09/1940
# 997  granite falls    nc     27040            NaN          nc    10/28/1931
# 998     siler city    nc     28466            NaN          mi    10/26/1938
# 999         lasker    nc     27284       000 0000          il    10/23/1940
#
#     download_month
# 0          2011-10
# 1          2011-12
# 2          2011-10
# 3          2011-10
# 4          2011-10
# ..             ...
# 995        2011-12
# 996        2011-12
# 997        2011-12
# 998        2011-12
# 999        2011-10
#
# [1000 rows x 19 columns]

# %%
df_shuffled.to_csv("../datasets/ncvoter_linha.csv", quotechar="\"")
